# %%
import pandas as pd

# %%
tp='OZ.csv'
OZ=pd.read_csv(tp)
OZ.head()
# Out:
#                                           Unnamed: 0  \
# 0  This document was updated December 14, 2018, t...
# 1  Please note that the below list of designated ...
# 2                          Bulletin at a later date.
# 3               Click arrow to filter state\n\nState
# 4                                            Alabama
#
#   Designated Qualified Opportunity Zones           Unnamed: 2  \
# 0                                    NaN                  NaN
# 1                                    NaN                  NaN
# 2                                    NaN                  NaN
# 3                                 County  Census Tract Number
# 4                                Autauga          01001020700
#
#              Unnamed: 3       Unnamed: 4
# 0                   NaN              NaN
# 1                   NaN              NaN
# 2                   NaN              NaN
# 3            Tract Type  ACS Data Source
# 4  Low-Income Community        2011-2015

# %%
df = OZ.set_index("Designated Qualified Opportunity Zones")

# %%
OZ1 = df.loc["Cook", "Unnamed: 2"]
OZ1.head()
# Out:
# Designated Qualified Opportunity Zones
# Cook    13075960200
# Cook    17031230600
# Cook    17031231200
# Cook    17031231500
# Cook    17031251300
# Name: Unnamed: 2, dtype: object

# %%
OZ_df=pd.DataFrame(OZ1)
OZ_df.to_csv('OZcook.csv')
OZ_df
# Out:
#                                          Unnamed: 2
# Designated Qualified Opportunity Zones
# Cook                                    13075960200
# Cook                                    17031230600
# Cook                                    17031231200
# Cook                                    17031231500
# Cook                                    17031251300
# Cook                                    17031251500
# Cook                                    17031251800
# Cook                                    17031251900
# Cook                                    17031260200
# Cook                                    17031260600
# Cook                                    17031270500
# Cook                                    17031271200
# Cook                                    17031271300
# Cook                                    17031271800
# Cook                                    17031280400
# Cook                                    17031280900
# ...
